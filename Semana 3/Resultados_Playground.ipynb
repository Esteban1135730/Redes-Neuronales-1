# %% [markdown]
# ## Registro de ejercicios y resultados – TensorFlow Playground
#
# Usa este cuaderno para **anotar lo que ves** en cada ejercicio:
#
# - Configuración que usaste (dataset, capas, neuronas, learning rate, activación, features).
# - Valores de `Training loss` y `Test loss`.
# - Comentario corto: ¿es buena/mala la configuración? ¿por qué?
#
# Sugerencia: rellena una tabla para cada ejercicio del PDF.

# %% [markdown]
# ### Ejercicio 1 – Two clusters (clasificación lineal)
#
# | Prueba | Dataset      | Hidden layers / neuronas | Activation | Learning rate | Features | Training loss | Test loss | Comentario |
# |--------|--------------|--------------------------|------------|---------------|----------|---------------|-----------|------------|
# | 1      | Two clusters | 1 capa, 1 neurona        | Tanh       | 0.03          | X1, X2   | ~0.02         | ~0.02     | Bueno. Funciona bien, los grupos se separan con una línea. https://playground.tensorflow.org/#activation=tanh&batchSize=16&dataset=gauss&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=1&seed=0.68088&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false|
# | 2      | Two clusters | 1 capa, 1 neurona        | ReLU       | 0.03          | X1, X2   | ~0.01         | ~0.01     | Bueno. ReLU aprende más rápido aquí. https://playground.tensorflow.org/#activation=relu&batchSize=16&dataset=gauss&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=1&seed=0.68088&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false|
# | 3      | Two clusters | 1 capa, 1 neurona        | Tanh       | 0.3           | X1, X2   | ~0.15-0.5     | ~0.2-0.5  | Malo. Tasa de aprendizaje demasiado alta, no converge. https://playground.tensorflow.org/#activation=tanh&batchSize=27&dataset=gauss&regDataset=reg-plane&learningRate=0.3&regularizationRate=0&noise=0&networkShape=1&seed=0.68088&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false|

# %% [markdown]
# ### Ejercicio 2 – Circle (frontera circular)
#
# | Prueba | Dataset | Hidden layers / neuronas | Activation | Learning rate | Features | Training loss | Test loss | Comentario |
# |--------|---------|--------------------------|------------|---------------|----------|---------------|-----------|------------|
# | 1      | Circle  | 1 capa, 1 neurona        | Tanh       | 0.03          | X1, X2   | ~0.4-0.5      | ~0.45     | Malo. Con 1 neurona solo se puede dibujar una línea, no un círculo.https://playground.tensorflow.org/#activation=tanh&batchSize=27&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=1&seed=0.00190&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false |
# | 2      | Circle  | 1 capa, 3 neuronas       | Tanh       | 0.03          | X1, X2   | ~0.05-0.1     | ~0.08     | Bueno. Con 3 neuronas ya se puede aproximar el círculo. https://playground.tensorflow.org/#activation=tanh&batchSize=27&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=3&seed=0.00190&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false|
# | 3      | Circle  | 1 capa, 6 neuronas       | Tanh       | 0.03          | X1, X2   | ~0.02-0.05    | ~0.04     | Bueno. Más neuronas mejoran el ajuste al círculo. https://playground.tensorflow.org/#activation=tanh&batchSize=27&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=6&seed=0.00190&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false|
# | 4      | Circle  | 2 capas, 4/4 neuronas    | Tanh       | 0.03          | X1, X2   | ~0.01-0.03    | ~0.02     | Muy bueno. Más capas captan mejor la forma circular.https://playground.tensorflow.org/#activation=tanh&batchSize=27&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,4&seed=0.00190&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false |

# %% [markdown]
# ### Ejercicio 3 – Gaussian (overfitting en clasificación)
#
# | Prueba | Dataset  | Hidden layers / neuronas | Activation | Learning rate | Features | Training loss | Test loss | Comentario |
# |--------|----------|--------------------------|------------|---------------|----------|---------------|-----------|------------|
# | 1      | Gaussian | 1 capa, 2 neuronas       | Tanh       | 0.03          | X1, X2   | ~0.15-0.25    | ~0.18     | Aceptable. Modelo simple que generaliza bien.https://playground.tensorflow.org/#activation=tanh&batchSize=27&dataset=gauss&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=2&seed=0.84934&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false |
# | 2      | Gaussian | 3 capas, 8 neuronas c/u  | Tanh       | 0.03          | X1, X2   | ~0.02-0.05    | ~0.2-0.35 | Overfitting. Aprende demasiado los datos de entrenamiento, no generaliza bien.https://playground.tensorflow.org/#activation=tanh&batchSize=27&dataset=gauss&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=8,8,8&seed=0.84934&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false |

# %% [markdown]
# ### Ejercicio 4 – XOR (features de entrada)
#
# | Prueba | Dataset | Hidden layers / neuronas | Activation | Learning rate | Features              | Training loss | Test loss | Comentario |
# |--------|---------|--------------------------|------------|---------------|-----------------------|---------------|-----------|------------|
# | 1      | XOR     | 1 capa, 2 neuronas       | Tanh       | 0.03          | X1, X2                | ~0.25-0.5     | ~0.3      | Malo. Con solo X1 y X2 la red no puede aprender XOR. https://playground.tensorflow.org/#activation=tanh&batchSize=27&dataset=xor&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=2&seed=0.71464&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false|
# | 2      | XOR     | 1 capa, 2 neuronas       | Tanh       | 0.03          | X1, X2, X1², X2², X1·X2 | ~0.01-0.05  | ~0.02     | Muy bueno. Con X1², X2² y X1·X2 la red sí aprende XOR. https://playground.tensorflow.org/#activation=tanh&batchSize=27&dataset=xor&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=2&seed=0.71464&showTestData=false&discretize=false&percTrainData=30&x=true&y=true&xTimesY=true&xSquared=true&ySquared=true&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false|

# %% [markdown]
# ### Ejercicios de regresión (6–10)
#
# | Prueba | Ejercicio      | Hidden layers / neuronas | Activation | Learning rate | Features              | Training loss | Test loss | Comentario |
# |--------|----------------|-------------------------|------------|---------------|-----------------------|---------------|-----------|------------|
# | 1      | Ej. 6 – Lineal | 0 capas                 | —          | 0.03          | X1                    | ~0.02         | ~0.02     | Bueno. Sin capas ocultas dibuja una recta; sirve si la relación es lineal. |
# | 2      | Ej. 6 – Lineal | 1 capa, 3 neuronas      | Tanh       | 0.03          | X1                    | ~0.01         | ~0.01     | Bueno. La capa oculta permite ajustar mejor la curva. |
# | 3      | Ej. 7 – No lineal   | 1 capa, 4 neuronas      | Tanh       | 0.03          | X1, X1²               | ~0.005        | ~0.01     | Bueno. X1² permite modelar curvas; el ajuste mejora. |
# | 4      | Ej. 7 – Sin X1²     | 1 capa, 4 neuronas      | Tanh       | 0.03          | X1                    | ~0.1-0.2      | ~0.15     | Malo. Sin X1² no puede modelar la curva; el error sube. |
# | 5      | Ej. 8 – LR bajo     | 2 capas, 5 neuronas     | Tanh       | 0.0001        | X1, X2                | ~0.05         | ~0.06     | Lento. Tarda mucho en aprender. |
# | 6      | Ej. 8 – LR medio    | 2 capas, 5 neuronas     | Tanh       | 0.03          | X1, X2                | ~0.01         | ~0.01     | Bueno. Aprende rápido y de forma estable. |
# | 7      | Ej. 8 – LR alto     | 2 capas, 5 neuronas     | Tanh       | 1             | X1, X2                | >0.5          | >0.5      | Malo. Tasa de aprendizaje demasiado alta; no converge. |
# | 8      | Ej. 9 – Simple      | 1 capa, 2 neuronas     | Tanh       | 0.03          | X1, X2                | ~0.02         | ~0.02     | Bueno. Modelo simple que generaliza bien. |
# | 9      | Ej. 9 – Complejo    | 3 capas, 8 neuronas c/u | Tanh       | 0.03          | X1, X2                | ~0.005        | ~0.03     | Overfitting. Aprende demasiado los datos de entrenamiento. |
# | 10     | Ej. 10 – Solo X1,X2 | 1 capa, 4 neuronas      | Tanh       | 0.03          | X1, X2                | ~0.02         | ~0.02     | Aceptable. Sirve para relaciones simples. |
# | 11     | Ej. 10 – Con features | 1 capa, 4 neuronas     | Tanh       | 0.03          | X1, X2, X1², X2², X1·X2 | ~0.005      | ~0.01     | Mejor. Más variables de entrada reducen el error. |
